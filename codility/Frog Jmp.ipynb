# %% [markdown]
# [문제 링크](https://app.codility.com/demo/results/trainingC5AGM9-5EA/)

# %% [markdown]
# ![Frog%20Jmp.png](attachment:Frog%20Jmp.png)

# %%
# X = 10; Y= 85; D=30
X = 1; Y= 5; D=2

import math

def solution(X, Y, D):
    temp = Y-X
    return math.ceil(temp/D)
