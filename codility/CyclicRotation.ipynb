# %% [markdown]
# ![CyclicRotation.png](attachment:CyclicRotation.png)

# %%
from collections import deque

# %%
deq = deque([3, 8, 9, 7, 6])
K=3

# %%
deq = deque([5, -1000])
K=1

# %%
from collections import deque

def solution(A, K):
    deq = deque(A)
    deq.rotate(K)
    return list(deq)
