# %% [markdown]
# ![OddOccurrencesInArray.png](attachment:OddOccurrencesInArray.png)

# %%
A = [9,3,9,3,9,7,9]

# %%
from collections import Counter

def solution(A):
    b = Counter(A)
    for val in set(A):
        if b[val]%2 == 1:
            return val
