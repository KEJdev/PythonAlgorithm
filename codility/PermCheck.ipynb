# %% [markdown]
# * [문제 링크](https://app.codility.com/demo/results/trainingX4BYAM-9P6/)

# %% [markdown]
# ![PermCheck.png](attachment:PermCheck.png)

# %%
A = [4,1,3,2]

# %%
A = [1,1]

# %%
A = [9, 5, 7, 3, 2, 7, 3, 1, 10, 11]

# %%
def solution(A):
    if len(A) != max(A) or len(set(A)) != len(A):
        return 0
    else:
        return 1

# %%
solution(A)
# Out:
# 0
