# %% [markdown]
# * [문제 링크](https://app.codility.com/demo/results/trainingRVZA5B-MAU/)

# %% [markdown]
# ![FrogRiverOne.png](attachment:FrogRiverOne.png)

# %%
A= [1,3,1,4,2,3,5,4] # return 6
X = 5

# %%
A = [1]
X = 1

# %%
def solution(X, A):  
    result = set()
    for idx,val in enumerate(A):
        if val <= X:
            result.add(val)

        if len(result) == X:
            return idx

    return -1
