# %% [markdown]
# * [문제 링크](https://app.codility.com/demo/results/trainingPP2WPP-SYR/)
# * 시간복잡도 O(n)

# %% [markdown]
# ![PermMissingElem.png](attachment:PermMissingElem.png)

# %%
A = [2, 3, 1, 5]
A = []
A = [2]
# Out:
# [2, 3, 1, 5]

# %%
def solution(A):
    if not A:
        return 1

    A = sorted(A) 
    for i,j in enumerate(A, start=1):
        if i != j :
            return i
    return i+1
